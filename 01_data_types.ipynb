# %% [markdown]
# # SUMARIZANDO
#
#
#
# | TIPO  |  ORDENADO | MUTÁVEL | CONSTRUTOR | EXEMPLO |
# |---|---|---|---|---|
# |int|-|-|int()|5|
# |float|-|-|float()|5.0|
# |string|S|N|'' "" str()|"Oi, eu sou o Goku"|
# |bool|-|-|-|True False|
# |list|S|S|[] list()|[23, 2, 275]|
# |tuple|S|N|() tuple()|(12, 27)|
# |set|N|S|{} set()|{32, 35}|
# |dictionary|N|N|{} dict|{"Fev": 28, "Out": 31}|
#
#
# | ARITMÉTICOS  |   | COMPARAÇÃO  |
# |---|---|---|
# | +  |   | <  |
# |  - |   |  <= |
# |  * |   |  > |
# | /  |   |  >= |
# | **  |   | ==  |
# | %  |   | !=  |
# |  // |   |   |
#
# ---
#
#
# ## INTRODUÇÃO
# ---
#
# ### 1. TIPOS DE DADOS E OPERADORES

# %%
print(3 + 5)
# Out:
# 8

# %% [markdown]
# #### 1.1 OPERADORES ARITMÉTICOS
# - +
# - -
# - *
# - /
# - %
# - **
# - //

# %%
print(1 + 2 * 5 * 2)
# Out:
# 21

# %% [markdown]
# #### 1.2 VARIÁVEIS

# %%
minha_idade = 23

# %%
print(minha_idade)
# Out:
# 23

# %%
x = 2
y = x
print(y)
# Out:
# 2

# %%
minha_idade, idade_carla, idade_julia = 23, 25, 30

# %%
print(minha_idade)
# Out:
# 23

# %%
print(idade_carla)
# Out:
# 25

# %%
print(idade_julia)
# Out:
# 30

# %%
valor = 0

print(valor)
# Out:
# 0

# %%
valor = 0
valor = valor * 2

print(valor)
# Out:
# 0

# %%
valor = 30
valor = 2

print(valor)
# Out:
# 15.0

# %%
nome = "Carla"
nome += " Giovana"

print(nome)
# Out:
# Carla Giovana

# %%
nome = "Carla"
nome += "2"

print(nome)
# Out:
# Carla2

# %% [markdown]
# #### 1.3 TIPOS DE DADOS
#
# - **int**: inteiros
# - **float**: decimais
# - **string**: textuais
# - **boolean**: True, False

# %%
tipo_int = 40
tipo_float = 40.01
tipo_string = "Bruna"
tipo_boolean = True

# %%
valor_velho = 40.0
valor_novo = int(valor_velho)

print(valor_novo)
# Out:
# 40

# %%
valor = "98727675"

print(int(valor) + 0)
# Out:
# 98727675

# %%
print(int(4.6))
# Out:
# 4

# %%
print(float(4))
# Out:
# 4.0

# %%
variavel = "4.3"
variavel = float(variavel)

print(variavel)
# Out:
# 4.3

# %%
validacao = True
validacao = False

# %%
print(bool(0))

# %%
print(x == 2)
# Out:
# True

# %%
print(bool(3290))

# %%
print(x != 2)
# Out:
# False

# %%
print(x >= 20)
# Out:
# False

# %%
print(x < -10)
# Out:
# False

# %%
print(x < 20 or x != 2)
# Out:
# True

# %%
print(not x % 2 == 0)
# Out:
# False

# %%
print("Feliz Ano Novo")
print('Feliz Natal')

# %%
print("I'm taking care of Roberto's TCC")
# Out:
# I'm taking care of Roberto's TCC

# %%
print("Eu falei assim para Jailsa: \"Eu não dou nem mais um real para você comprar o ovo\"")
# Out:
# Eu falei assim para Jailsa: "Eu não dou nem mais um real para você comprar o ovo"

# %%
print("OI, MEU NOME É JOANA. \\\" OI, MEU NOME É ITALO")
# Out:
# OI, MEU NOME É JOANA. \" OI, MEU NOME É ITALO

# %% [markdown]
# ##### 1.3.1 ALGUNS MÉTODOS DE STRINGS

# %%
valor = "192,89090"

valor = valor.replace(",890", ".")

valor, type(valor)
# Out:
# ('192.90', str)

# %%
valor = float(valor)

valor, type(valor)
# Out:
# (192.9, float)

# %%
meu_nome = "   iTALO oLIVEIRA"
meu_nome = meu_nome.title()

meu_nome
# Out:
# '   Italo Oliveira'

# %%
meu_nome, len(meu_nome)
# Out:
# ('   Italo Oliveira', 17)

# %%
meu_nome = meu_nome.strip()

meu_nome, len(meu_nome)
# Out:
# ('Italo Oliveira', 14)

# %%
meu_nome[3]
# Out:
# 'l'

# %%
meu_nome.index(" ")
# Out:
# 5

# %%
space_index = meu_nome.index(" ")

# %%
first_name = meu_nome[0:space_index]

first_name
# Out:
# 'Italo'

# %%
meu_nome[space_index + 1:len(meu_nome)]
# Out:
# 'Oliveira'

# %%
len(meu_nome)
# Out:
# 14

# %%
meu_nome
# Out:
# 'Italo Oliveira'

# %%
last_name = meu_nome[space_index + 1:len(meu_nome)]
last_name
# Out:
# 'Oliveira'

# %%
meu_nome
# Out:
# 'Italo Oliveira'

# %%
meu_nome
# Out:
# 'Italo Oliveira'

# %%
first_name + last_name
# Out:
# 'ItaloOliveira'

# %%
story = "A vaca pulou sobre o riacho"
story.split(" ")
# Out:
# ['A', 'vaca', 'pulou', 'sobre', 'o', 'riacho']

# %%
story_list = story.split(" ")
len(story_list)
# Out:
# 6

# %%
story_list[1]
# Out:
# 'vaca'

# %%
story_list[3][:2]
# Out:
# 'so'

# %% [markdown]
# ##### 1.3.2 ALGUNS MÉTODOS DE LISTAS

# %%
story_pt2 = "e deu um coice na Maria"

story_list.append(story_pt2)

# %%
story_list
# Out:
# ['A', 'vaca', 'pulou', 'sobre', 'o', 'riacho', 'e deu um coice na Maria']

# %%
story_list = story_list[:-1]

# %%
story_list
# Out:
# ['A', 'vaca', 'pulou', 'sobre', 'o', 'riacho']

# %%
story_pt2.split(" ")
# Out:
# ['e', 'deu', 'um', 'coice', 'na', 'Maria']

# %%
for x in story_pt2.split(" "):
  story_list.append(x)

# %%
story_list
# Out:
# ['A',
#  'vaca',
#  'pulou',
#  'sobre',
#  'o',
#  'riacho',
#  'e',
#  'deu',
#  'um',
#  'coice',
#  'na',
#  'Maria']

# %%
final_story = " ".join(story_list)

final_story
# Out:
# 'A vaca pulou sobre o riacho e deu um coice na Maria'

# %%
lista = []

valores1 = [1, 2, 3, 4]
valores2 = [10, 9, 8]

# %%
lista.extend(valores1)

# %%
rand_list = [1, 4, "Joana", 0 == 1, False]

# %%
rand_list
# Out:
# [1, 4, 'Joana', False, False]

# %%
rand_list[4] = True

# %%
rand_list
# Out:
# [1, 4, 'Joana', False, True]

# %%
dice_numbers = [3, 2, 1, 6, 5, 4]

# %%
len(dice_numbers)
# Out:
# 6

# %%
max(dice_numbers)
# Out:
# 6

# %%
min(dice_numbers)
# Out:
# 1

# %%
sorted(dice_numbers)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
coordenadas = (13.4125, 103.866667)
print("Latitude:", coordenadas[0])
print("Longitude:", coordenadas[1])
# Out:
# Latitude: 13.4125
# Longitude: 103.866667

# %%
coordenadas[0] = 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-151-7db676ec836f> in <module>()
# ----> 1 coordenadas[0] = 2
#
# TypeError: 'tuple' object does not support item assignment

# %%
coordenadas = tuple(coordenadas)

# %%
dimensoes = 52, 40, 100
comprimento, largura, altura = dimensoes
print("O produto tem as seguintes dimensões: {} cm x {} cm x {} cm".format(comprimento, largura, altura))
# Out:
# O produto tem as seguintes dimensões: 52 cm x 40 cm x 100 cm

# %%
type(dimensoes)
# Out:
# tuple

# %%
lista_de_compras = ["banana", "uva", "pera", "banana", "ovo", "uva"]
set(lista_de_compras)
# Out:
# {'banana', 'ovo', 'pera', 'uva'}

# %%
nomes_unicos = {"Joao", "Joana", "Joaquim", "Joao"}
nomes_unicos
# Out:
# {'Joana', 'Joao', 'Joaquim'}

# %%
user_profile = {
    "Nome": "Beatriz Pereira dos Santos",
    "Idade": 33,
    "Profissão": "Ufóloga",
    "Hobbies": ["Basquete", "Séries", "Fotografia"]
}

# %%
user_profile["Idade"]
# Out:
# 33

# %%
user_profile["Profissão"]
# Out:
# 'Ufóloga'

# %%
user_profile["Profissão"] = "Médica"

# %%
user_profile
# Out:
# {'Genero': 'Feminino',
#  'Hobbies': ['Basquete', 'Séries', 'Fotografia'],
#  'Idade': 33,
#  'Nome': 'Beatriz Pereira dos Santos',
#  'Profissão': 'Médica'}

# %%
import pandas as pd

# %%
df = pd.DataFrame({"nome": ["Italo", "Bruna", "Mauraia"], "idade": [23, 24, 25]})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
# nome     3 non-null object
# idade    3 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 176.0+ bytes
